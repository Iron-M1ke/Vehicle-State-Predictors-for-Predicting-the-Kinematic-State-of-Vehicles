# %%
# !pip install folium
# Out:
# Requirement already satisfied: folium in c:\users\olive\anaconda3\lib\site-packages (0.14.0)
# Requirement already satisfied: numpy in c:\users\olive\anaconda3\lib\site-packages (from folium) (1.22.3)
# Requirement already satisfied: jinja2>=2.9 in c:\users\olive\anaconda3\lib\site-packages (from folium) (2.11.2)
# Requirement already satisfied: branca>=0.6.0 in c:\users\olive\anaconda3\lib\site-packages (from folium) (0.6.0)
# Requirement already satisfied: requests in c:\users\olive\anaconda3\lib\site-packages (from folium) (2.24.0)
# Requirement already satisfied: MarkupSafe>=0.23 in c:\users\olive\anaconda3\lib\site-packages (from jinja2>=2.9->folium) (1.1.1)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in c:\users\olive\anaconda3\lib\site-packages (from requests->folium) (1.25.9)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\olive\anaconda3\lib\site-packages (from requests->folium) (2020.6.20)
# Requirement already satisfied: idna<3,>=2.5 in c:\users\olive\anaconda3\lib\site-packages (from requests->folium) (2.10)
# Requirement already satisfied: chardet<4,>=3.0.2 in c:\users\olive\anaconda3\lib\site-packages (from requests->folium) (3.0.4)

# %%
#import ray
#import tensorflow as tf

import time
import numpy as np
import pandas as pd
import sklearn 
import seaborn as sns
import matplotlib.pyplot as plt
import geopandas as gpd
import plotly_express as px
import folium

from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error
from sklearn.model_selection import cross_val_predict
from sklearn.metrics import mean_squared_error, r2_score

# %%
#import dataset
db = pd.read_csv("tracklets.csv")
db
# Out:
#     idtracklet|id1|mmsi1|speed1|course1|heading1|lon1|lat1|ts1|id2|mmsi2|speed2|course2|heading2|lon2|lat2|ts2|id3|mmsi3|speed3|course3|heading3|lon3|lat3|ts3|id4|mmsi4|speed4|course4|heading4|lon4|lat4|ts4|id5|mmsi5|speed5|course5|heading5|lon5|lat5|ts5|route
# 0    1|4128997|228005700|6.7|175|511|-4.551695|48.3...
# 1    2|14817869|249104000|8.7|69|69|-4.733975|48.30...
# 2    3|8618319|228017700|14.6|83.7|86|-4.885512|48....
# 3    4|16024159|227008170|12.3|125|126|-4.924165|48...
# 4    5|2144526|228017700|16.5|73.4|73|-4.550415|48....
# ..                                                 ...
# 795  796|3554186|227730220|19.1|56.9|511|-4.639665|...
# 796  797|1585479|227005550|23.1|68.9|511|-4.547798|...
# 797  798|2761022|258316000|12.1|338|332|-5.186498|4...
# 798  799|5167729|228186700|10.9|104|103|-4.465165|4...
# 799  800|1922119|227364000|8.8|303.4|308|-4.773423|...
#
# [800 rows x 1 columns]

# %%
#re-import dataset and set delimiter
db = pd.read_csv("tracklets.csv", sep="|")
db
# Out:
#      idtracklet       id1      mmsi1  speed1  course1  heading1      lon1  \
# 0             1   4128997  228005700     6.7    175.0       511 -4.551695
# 1             2  14817869  249104000     8.7     69.0        69 -4.733975
# 2             3   8618319  228017700    14.6     83.7        86 -4.885512
# 3             4  16024159  227008170    12.3    125.0       126 -4.924165
# 4             5   2144526  228017700    16.5     73.4        73 -4.550415
# ..          ...       ...        ...     ...      ...       ...       ...
# 795         796   3554186  227730220    19.1     56.9       511 -4.639665
# 796         797   1585479  227005550    23.1     68.9       511 -4.547798
# 797         798   2761022  258316000    12.1    338.0       332 -5.186498
# 798         799   5167729  228186700    10.9    104.0       103 -4.465165
# 799         800   1922119  227364000     8.8    303.4       308 -4.773423
#
#           lat1         ts1       id2  ...         ts4       id5      mmsi5  \
# 0    48.344520  1447148032   4129047  ...  1447148121   4129188  228005700
# 1    48.301247  1456438812  14817884  ...  1456438842  14817927  249104000
# 2    48.404390  1451215056   8618323  ...  1451215075   8618335  228017700
# 3    48.405033  1457099514  16024163  ...  1457099527  16024186  227008170
# 4    48.351140  1445447976   2144611  ...  1445448112   2144738  228017700
# ..         ...         ...       ...  ...         ...       ...        ...
# 795  48.315987  1446681907   3554191  ...  1446681925   3554214  227730220
# 796  48.351620  1444922333   1585481  ...  1444922338   1585485  227005550
# 797  48.084835  1445959658   2761038  ...  1445959718   2761117  258316000
# 798  48.318333  1448009887   5167735  ...  1448009892   5167744  228186700
# 799  48.041780  1445255813   1922136  ...  1445255852   1922194  227364000
#
#      speed5  course5  heading5      lon5       lat5         ts5  route
# 0       3.9    325.8       511 -4.551893  48.343353  1447148153   R_07
# 1       8.5     68.5        69 -4.731818  48.301840  1456438851   R_14
# 2      14.7     84.3        88 -4.882973  48.404560  1451215081   R_01
# 3      12.4    130.0       119 -4.922998  48.404335  1457099531   R_11
# 4      16.0     72.7        71 -4.535050  48.354515  1445448122   R_06
# ..      ...      ...       ...       ...        ...         ...    ...
# 795    19.5     55.2       511 -4.636951  48.317173  1446681932    R_0
# 796    23.2     69.3       511 -4.547202  48.351772  1444922338    R_0
# 797    12.2    337.0       333 -5.188832  48.088500  1445959727    R_0
# 798    10.9    105.0       101 -4.464665  48.318165  1448009893    R_0
# 799     8.6    305.3       312 -4.775925  48.042880  1445255863    R_0
#
# [800 rows x 42 columns]

# %%
#examine dataset
print("---cc---")
print(db.info())
# Out:
# ---cc---
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 800 entries, 0 to 799
# Data columns (total 42 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   idtracklet  800 non-null    int64
#  1   id1         800 non-null    int64
#  2   mmsi1       800 non-null    int64
#  3   speed1      800 non-null    float64
#  4   course1     800 non-null    float64
#  5   heading1    800 non-null    int64
#  6   lon1        800 non-null    float64
#  7   lat1        800 non-null    float64
#  8   ts1         800 non-null    int64
#  9   id2         800 non-null    int64
#  10  mmsi2       800 non-null    int64
#  11  speed2      800 non-null    float64
#  12  course2     800 non-null    float64
#  13  heading2    800 non-null    int64
#  14  lon2        800 non-null    float64
#  15  lat2        800 non-null    float64
#  16  ts2         800 non-null    int64
#  17  id3         800 non-null    int64
#  18  mmsi3       800 non-null    int64
#  19  speed3      800 non-null    float64
#  20  course3     800 non-null    float64
#  21  heading3    800 non-null    int64
#  22  lon3        800 non-null    float64
#  23  lat3        800 non-null    float64
#  24  ts3         800 non-null    int64
#  25  id4         800 non-null    int64
#  26  mmsi4       800 non-null    int64
#  27  speed4      800 non-null    float64
#  28  course4     800 non-null    float64
#  29  heading4    800 non-null    int64
#  30  lon4        800 non-null    float64
#  31  lat4        800 non-null    float64
#  32  ts4         800 non-null    int64
#  33  id5         800 non-null    int64
#  34  mmsi5       800 non-null    int64
#  35  speed5      800 non-null    float64
#  36  course5     800 non-null    float64
#  37  heading5    800 non-null    int64
#  38  lon5        800 non-null    float64
#  39  lat5        800 non-null    float64
#  40  ts5         800 non-null    int64
#  41  route       800 non-null    object
# dtypes: float64(20), int64(21), object(1)
# memory usage: 262.6+ KB
# None

# %%
print("Tracklets Rows: ", db.shape[0])
print("Tracklets Columns: ", db.shape[1])
# Out:
# Tracklets Rows:  800
# Tracklets Columns:  42

# %%
#heatmap to detect null values
sns.heatmap(db.isnull(), cmap="RdBu", cbar=False)

# %%
#drop potential na values
db.dropna(inplace=True)
db.head(20)
# Out:
#     idtracklet       id1      mmsi1  speed1  course1  heading1      lon1  \
# 0            1   4128997  228005700     6.7    175.0       511 -4.551695
# 1            2  14817869  249104000     8.7     69.0        69 -4.733975
# 2            3   8618319  228017700    14.6     83.7        86 -4.885512
# 3            4  16024159  227008170    12.3    125.0       126 -4.924165
# 4            5   2144526  228017700    16.5     73.4        73 -4.550415
# 5            6  10079397  227008170    14.6     80.0        72 -4.617865
# 6            7   2368660  228017700    15.2     90.1        90 -4.699847
# 7            8  17841293  227008170    14.1     64.0        61 -4.584715
# 8            9  10064416  228005700     7.6    354.9       511 -4.590128
# 9           10   3195658  227104210     6.2      1.5       511 -4.588353
# 10          11  10088009  228017700    13.7    136.6       140 -4.833275
# 11          12   7884537  227002630    13.9    255.1       252 -4.361738
# 12          13  16893839  227003050    14.4     82.8        73 -4.763814
# 13          14   5473627  228017700    15.3     84.5        86 -4.733942
# 14          15   6558378  227008170    12.6    137.0       136 -4.821348
# 15          16   1822437  227276230    19.7    230.9       511 -4.572623
# 16          17  12006767  228017700    17.6    141.8       132 -4.796170
# 17          18  10092828  228017700    15.8     92.2        96 -4.725370
# 18          19   9626362  227002630    13.9    271.4       266 -4.372173
# 19          20  10029273  227008170    11.6    256.0       254 -4.608965
#
#          lat1         ts1       id2  ...         ts4       id5      mmsi5  \
# 0   48.344520  1447148032   4129047  ...  1447148121   4129188  228005700
# 1   48.301247  1456438812  14817884  ...  1456438842  14817927  249104000
# 2   48.404390  1451215056   8618323  ...  1451215075   8618335  228017700
# 3   48.405033  1457099514  16024163  ...  1457099527  16024186  227008170
# 4   48.351140  1445447976   2144611  ...  1445448112   2144738  228017700
# 5   48.332535  1452784073  10079406  ...  1452784088  10079437  227008170
# 6   48.326090  1445624212   2368665  ...  1445624237   2368676  228017700
# 7   48.338530  1458921245  17841302  ...  1458921262  17841322  227008170
# 8   48.305687  1452774678  10064467  ...  1452774768  10064618  228005700
# 9   48.314884  1446392149   3195686  ...  1446392236   3195773  227104210
# 10  48.392220  1452788939  10088008  ...  1452788943  10088020  228017700
# 11  48.121980  1450343707   7884546  ...  1450343728   7884583  227002630
# 12  48.319653  1458062292  16893841  ...  1458062298  16893857  227003050
# 13  48.325253  1448212247   5473836  ...  1448212435   5473955  228017700
# 14  48.382900  1449147733   6558392  ...  1449147763   6558440  227008170
# 15  48.332718  1445162490   1822464  ...  1445162579   1822546  227276230
# 16  48.359480  1454240312  12006768  ...  1454240321  12006781  228017700
# 17  48.325737  1452791783  10092835  ...  1452791904  10093006  228017700
# 18  48.118885  1452330949   9626365  ...  1452331081   9626449  227002630
# 19  48.334766  1452754851  10029290  ...  1452754881  10029329  227008170
#
#     speed5  course5  heading5      lon5       lat5         ts5  route
# 0      3.9    325.8       511 -4.551893  48.343353  1447148153   R_07
# 1      8.5     68.5        69 -4.731818  48.301840  1456438851   R_14
# 2     14.7     84.3        88 -4.882973  48.404560  1451215081   R_01
# 3     12.4    130.0       119 -4.922998  48.404335  1457099531   R_11
# 4     16.0     72.7        71 -4.535050  48.354515  1445448122   R_06
# 5     14.3     75.0        70 -4.615698  48.332882  1452784095   R_06
# 6     15.3     87.4        88 -4.696712  48.326225  1445624241   R_06
# 7     13.9     65.0        67 -4.582665  48.339170  1458921268   R_11
# 8      8.4      6.5       511 -4.590462  48.310192  1452774801   R_08
# 9      6.9      8.9       511 -4.587835  48.318478  1446392266   R_08
# 10    13.8    136.4       139 -4.832873  48.391945  1452788944   R_11
# 11    14.0    257.4       252 -4.364284  48.121580  1450343735   R_12
# 12    14.5     78.0        75 -4.763134  48.319786  1458062299   R_06
# 13    14.8     83.3        84 -4.713597  48.326447  1448212442   R_06
# 14    12.3    136.0       136 -4.819065  48.381317  1449147772   R_11
# 15    20.0    210.8       511 -4.585175  48.325447  1445162610   R_07
# 16    17.7    140.5       128 -4.795387  48.358852  1454240323   R_01
# 17    15.8     91.8        90 -4.712148  48.325336  1452791904   R_06
# 18    13.8    280.8       274 -4.387797  48.119766  1452331113   R_12
# 19    11.5    258.0       258 -4.612082  48.334232  1452754890   R_05
#
# [20 rows x 42 columns]

# %%
#heatmap to detect null values
sns.heatmap(db.isnull(), cmap="RdBu", cbar=False)

# %%
#only needed if you need to read the UNIX timestamps

#process timestamps to human readable format
#db['ts1'] = pd.to_datetime(db['ts1'], unit='s')
#db['ts2'] = pd.to_datetime(db['ts2'], unit='s')
#db['ts3'] = pd.to_datetime(db['ts3'], unit='s')
#db['ts4'] = pd.to_datetime(db['ts4'], unit='s')
#db['ts5'] = pd.to_datetime(db['ts5'], unit='s')
#db

# %%
#introduce a correlation matrix
cm = db.corr()

# %%
#feature and target selection
features = ['speed1', 'course1', 'heading1', 'ts1', 'speed2', 'course2', 'heading2', 'ts2', 'speed3', 'course3', 'heading3', 'ts3', 'speed4', 'course4', 'heading4', 'ts4', 'speed5', 'course5', 'heading5', 'ts5']  
targets = ['lon1', 'lat1', 'lon2', 'lat2', 'lon3', 'lat3', 'lon4', 'lat4', 'lon5', 'lat5']  

x = db[features]
y = db[targets]

original_lon1 = db["lon1"]
original_lat1 = db["lat1"]

# %%
#examine x then y
x
# Out:
#      speed1  course1  heading1         ts1  speed2  course2  heading2  \
# 0       6.7    175.0       511  1447148032     6.9    175.5       511
# 1       8.7     69.0        69  1456438812     8.5     69.1        68
# 2      14.6     83.7        86  1451215056    14.7     83.7        86
# 3      12.3    125.0       126  1457099514    12.6    130.0       125
# 4      16.5     73.4        73  1445447976    16.0     70.3        69
# ..      ...      ...       ...         ...     ...      ...       ...
# 795    19.1     56.9       511  1446681907    19.5     57.7       511
# 796    23.1     68.9       511  1444922333    23.2     69.1       511
# 797    12.1    338.0       332  1445959658    12.1    338.0       332
# 798    10.9    104.0       103  1448009887    10.9    104.0       102
# 799     8.8    303.4       308  1445255813     8.8    302.6       309
#
#             ts2  speed3  course3  heading3         ts3  speed4  course4  \
# 0    1447148061     2.8    215.6       511  1447148092     2.1    337.5
# 1    1456438821     8.5     68.3        69  1456438832     8.6     67.9
# 2    1451215063    14.7     83.8        86  1451215069    14.6     84.1
# 3    1457099516    12.8    132.0       124  1457099521    12.5    131.0
# 4    1445448036    15.8     70.5        71  1445448052    16.1     72.8
# ..          ...     ...      ...       ...         ...     ...      ...
# 795  1446681913    19.9     59.2       511  1446681919    19.0     55.4
# 796  1444922335    23.2     69.3       511  1444922337    23.2     69.7
# 797  1445959667    12.2    338.0       332  1445959677    12.2    337.0
# 798  1448009889    10.9    105.0       102  1448009890    10.9    107.0
# 799  1445255823     8.7    303.0       308  1445255832     8.7    302.0
#
#      heading4         ts4  speed5  course5  heading5         ts5
# 0         511  1447148121     3.9    325.8       511  1447148153
# 1          69  1456438842     8.5     68.5        69  1456438851
# 2          87  1451215075    14.7     84.3        88  1451215081
# 3         121  1457099527    12.4    130.0       119  1457099531
# 4          73  1445448112    16.0     72.7        71  1445448122
# ..        ...         ...     ...      ...       ...         ...
# 795       511  1446681925    19.5     55.2       511  1446681932
# 796       511  1444922338    23.2     69.3       511  1444922338
# 797       333  1445959718    12.2    337.0       333  1445959727
# 798       101  1448009892    10.9    105.0       101  1448009893
# 799       311  1445255852     8.6    305.3       312  1445255863
#
# [800 rows x 20 columns]

# %%
y
# Out:
#          lon1       lat1      lon2       lat2      lon3       lat3      lon4  \
# 0   -4.551695  48.344520 -4.551470  48.343616 -4.551337  48.342773 -4.551582
# 1   -4.733975  48.301247 -4.733532  48.301365 -4.732932  48.301537 -4.732377
# 2   -4.885512  48.404390 -4.884903  48.404434 -4.884294  48.404472 -4.883685
# 3   -4.924165  48.405033 -4.923965  48.404915 -4.923698  48.404750 -4.923248
# 4   -4.550415  48.351140 -4.544022  48.352585 -4.542357  48.352993 -4.536008
# ..        ...        ...       ...        ...       ...        ...       ...
# 795 -4.639665  48.315987 -4.639073  48.316227 -4.638355  48.316505 -4.637738
# 796 -4.547798  48.351620 -4.547500  48.351700 -4.547202  48.351772 -4.546900
# 797 -5.186498  48.084835 -5.186832  48.085335 -5.187165  48.086000 -5.188498
# 798 -4.465165  48.318333 -4.464998  48.318165 -4.464832  48.318165 -4.464665
# 799 -4.773423  48.041780 -4.773940  48.041990 -4.774435  48.042206 -4.775448
#
#           lat4      lon5       lat5
# 0    48.342983 -4.551893  48.343353
# 1    48.301685 -4.731818  48.301840
# 2    48.404514 -4.882973  48.404560
# 3    48.404500 -4.922998  48.404335
# 4    48.354320 -4.535050  48.354515
# ..         ...       ...        ...
# 795  48.316814 -4.636951  48.317173
# 796  48.351845 -4.547202  48.351772
# 797  48.088000 -5.188832  48.088500
# 798  48.318165 -4.464665  48.318165
# 799  48.042640 -4.775925  48.042880
#
# [800 rows x 10 columns]

# %%
#split dataset for training and testing
X_train, X_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=42)

#create linear regression model
lon_model = LinearRegression()
lat_model = LinearRegression()

# %%
#fit the model
lon_model.fit(X_train, y_train['lon1'])  #longitude prediction
lat_model.fit(X_train, y_train['lat1'])  #latitude prediction
# Out:
# LinearRegression()

# %%
#predict the model
lon_predictions = lon_model.predict(X_test)
lat_predictions = lat_model.predict(X_test)

# %%
#predicted longitude and latitude values

#print(lon_predictions)
#print(lat_predictions)

lon_lat_p = pd.DataFrame({
    "Longitude": lon_predictions,
    "Latitude": lat_predictions
})

lon_lat_p
# Out:
#      Longitude   Latitude
# 0    -4.644427  48.254778
# 1    -4.777951  48.272358
# 2    -4.707740  48.307352
# 3    -4.706132  48.270410
# 4    -4.671591  48.304778
# ..         ...        ...
# 155  -4.593279  48.296151
# 156  -4.745788  48.274850
# 157  -4.589265  48.507345
# 158  -4.745430  48.275080
# 159  -4.618993  48.281659
#
# [160 rows x 2 columns]

# %%
from shapely.geometry import Point
#create a geometry column using Point objects from the shapley library
geometry = [Point(lon, lat) for lon, lat in zip(lon_predictions, lat_predictions)]

#create the GeoDataFrame
geo_df = gpd.GeoDataFrame({
    'Longitude': lon_predictions,
    'Latitude': lat_predictions
}, geometry=geometry)

print(geo_df)
# Out:
#      Longitude   Latitude                   geometry
# 0    -4.644427  48.254778  POINT (-4.64443 48.25478)
# 1    -4.777951  48.272358  POINT (-4.77795 48.27236)
# 2    -4.707740  48.307352  POINT (-4.70774 48.30735)
# 3    -4.706132  48.270410  POINT (-4.70613 48.27041)
# 4    -4.671591  48.304778  POINT (-4.67159 48.30478)
# ..         ...        ...                        ...
# 155  -4.593279  48.296151  POINT (-4.59328 48.29615)
# 156  -4.745788  48.274850  POINT (-4.74579 48.27485)
# 157  -4.589265  48.507345  POINT (-4.58927 48.50734)
# 158  -4.745430  48.275080  POINT (-4.74543 48.27508)
# 159  -4.618993  48.281659  POINT (-4.61899 48.28166)
#
# [160 rows x 3 columns]

# %%
o_geometry = [Point(lon, lat) for lon, lat in zip(original_lon1, original_lat1)]

#create the GeoDataFrame
o_geo_df = gpd.GeoDataFrame({
    'Longitude': original_lon1,
    'Latitude': original_lat1
}, geometry=o_geometry)

print(o_geo_df)
# Out:
#      Longitude   Latitude                   geometry
# 0    -4.551695  48.344520  POINT (-4.55169 48.34452)
# 1    -4.733975  48.301247  POINT (-4.73398 48.30125)
# 2    -4.885512  48.404390  POINT (-4.88551 48.40439)
# 3    -4.924165  48.405033  POINT (-4.92417 48.40503)
# 4    -4.550415  48.351140  POINT (-4.55042 48.35114)
# ..         ...        ...                        ...
# 795  -4.639665  48.315987  POINT (-4.63966 48.31599)
# 796  -4.547798  48.351620  POINT (-4.54780 48.35162)
# 797  -5.186498  48.084835  POINT (-5.18650 48.08483)
# 798  -4.465165  48.318333  POINT (-4.46516 48.31833)
# 799  -4.773423  48.041780  POINT (-4.77342 48.04178)
#
# [800 rows x 3 columns]

# %%
#data visualisation

#create a map centered around the mean coordinates of the points
mean_coords = geo_df['geometry'].unary_union.centroid
m = folium.Map(location=[mean_coords.y, mean_coords.x], zoom_start=6)

#add original geometry
for index, row in o_geo_df.iterrows():
    lat, lon = row['geometry'].y, row['geometry'].x  # Use 'geometry' here
    folium.CircleMarker([lat, lon], radius=5, color='blue', fill=True, fill_color='blue').add_to(m)

#add predictions markers
for index, row in geo_df.iterrows():
    lat, lon = row['geometry'].y, row['geometry'].x
    folium.CircleMarker([lat, lon], radius=5, color='red', fill=True, fill_color='red').add_to(m)


#display the map
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_fded080de29e1e5a1fc1d5005218d03d {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_fded080de29e1e5a1fc1d5005218d03d&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_fded080de29e1e5a1fc1d5005218d03d = L.map(
#                 &quot;map_fded080de29e1e5a1fc1d5005218d03d&quot;,
#                 {
#                     center: [48.284458342572016, -4.691991059576829],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 6,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_f8ec619be876976c0915418c59d4944c = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_fded080de29e1e5a1fc1d5005218d03d);
#
#
#             var circle_marker_0aa26643c77b801fbbeac57e8a99f384 = L.circleMarker(
#                 [48.34452, -4.551695],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 5, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_fded080de29e1e5a1fc1d5005218d03d);
#
#
#             var circle_marker_9241f450d60a73b2110e3bb9af08caf0 = L.circleMarker(
#                 [48.301247, -4.733975],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 5, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_fded080de29e1e5a1fc1d5005218d03d);
#
#
#             var circle_marker_a4e5acedaf09e25ad3a63310e0eea91a = L.circleMarker(
#                 [48.40439, -4.885512],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 5, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_fded080de29e1e5a1fc1d5005218d03d);
#
#
#             var circle_marker_0251d2dc23a81590b95cf8415d230433 = L.circleMarker(
#                 [48.405033, -4.924165],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 5, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_fded080de29e1e5a1fc1d5005218d03d);
#
#
#             var circle_marker_7307b92db68bd37bc960e13ff4a71ec7 = L.circleMarker(
#                 [48.35114, -4.550415],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 5, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_fded080de29e1e5a1fc1d5005218d03d);
#
#
#             var circle_marker_175bbc3d1ea3062ab89776851a313cbc = L.circleMarker(
#                 [48.332535, -4.617865],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 5, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_fded080de29e1e5a1fc1d5005218d03d);
#
#
#             var circle_marker_83a0405d02a5410fb363e113032105d6 = L.circleMarker(

# %% [markdown]
# Here is a general breakdown on vessel prediction using data visualisation. The abouve could indicate that vessels, in general, are coming into port as the data markers seem to congregate around port areas. However, some outliers show some predictions as being on land - we will analyse a vessel showing some inconsistent results shoiwng "land prediction abnormality" in the next section.

# %%
#choose vessel you want to track
selected_mmsi = 227008170 

#filter dataset for selected vessel
selected_vessel_data = db[db['mmsi1'] == selected_mmsi]

#feature and target selection
selected_features = ['speed1', 'course1', 'heading1', 'ts1', 'speed2', 'course2', 'heading2', 'ts2', 'speed3', 'course3', 'heading3', 'ts3', 'speed4', 'course4', 'heading4', 'ts4', 'speed5', 'course5', 'heading5', 'ts5']
selected_targets = ['lon1', 'lat1', 'lon2', 'lat2', 'lon3', 'lat3', 'lon4', 'lat4', 'lon5', 'lat5']  

x_selected = selected_vessel_data[selected_features]
y_selected = selected_vessel_data[selected_targets]

#split training and testing data
X_train_sel, X_test_sel, y_train_sel, y_test_sel = train_test_split(x_selected, y_selected, test_size=0.2, random_state=42)

#create linear regression models for each coordinate
lon_models_sel = [LinearRegression() for _ in selected_targets[::2]]
lat_models_sel = [LinearRegression() for _ in selected_targets[1::2]]

#fit models for each coordinate
for lon_model, lat_model, lon_target, lat_target in zip(lon_models_sel, lat_models_sel, selected_targets[::2], selected_targets[1::2]):
    lon_model.fit(X_train_sel, y_train_sel[lon_target])
    lat_model.fit(X_train_sel, y_train_sel[lat_target])

#predict models for each coordinate
lon_predictions_sel = [lon_model.predict(X_test_sel) for lon_model in lon_models_sel]
lat_predictions_sel = [lat_model.predict(X_test_sel) for lat_model in lat_models_sel]

#create the DataFrame for the predicted values
lon_lat_p_sel = pd.DataFrame({
    f"Longitude_{i}": lon_pred for i, lon_pred in enumerate(lon_predictions_sel)
})

# Combine the predicted values for longitude and latitude
lon_values = [lon_pred for lon_pred_list in lon_predictions_sel for lon_pred in lon_pred_list]
lat_values = [lat_pred for lat_pred_list in lat_predictions_sel for lat_pred in lat_pred_list]

#create thee GeoDataFrames
geometry_sel = [Point(lon, lat) for lon, lat in zip(lon_values, lat_values)]
geo_df_sel = gpd.GeoDataFrame({
    'Longitude': lon_values,
    'Latitude': lat_values
}, geometry=geometry_sel)


selected_geometry = [Point(lon, lat) for lon, lat in zip(selected_vessel_data['lon1'], selected_vessel_data['lat1'])]
selected_geo_df = gpd.GeoDataFrame({
    'Longitude': selected_vessel_data['lon1'],
    'Latitude': selected_vessel_data['lat1']
}, geometry=selected_geometry)

#add an 'Origin' column to indicate whether a position is 'Original' or 'Predicted'
selected_geo_df['Origin'] = 'Original'
geo_df_sel['Origin'] = 'Predicted'

#combine original and predicted positions into a single GeoDataFrame
combined_geo_df = pd.concat([selected_geo_df, geo_df_sel])

#create a map centered around the mean coordinates of the points
mean_coords_combined = combined_geo_df['geometry'].unary_union.centroid
m_combined = folium.Map(location=[mean_coords_combined.y, mean_coords_combined.x], zoom_start=9)

#add the combined GeoDataFrame as map markers
for index, row in combined_geo_df.iterrows():
    lat, lon = row['geometry'].y, row['geometry'].x
    origin = row['Origin']

    if origin == 'Original':
        color = 'blue'
        label = f"Original {index}" 
    else:
        color = 'red'
        label = f"Predicted {index}"  

    folium.CircleMarker([lat, lon], radius=5, color=color, fill=True, fill_color=color, popup=folium.Popup(label)).add_to(m_combined)

#display the map
m_combined
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_bd44f82f655b19277c3ee1d3d6a6fcc9 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_bd44f82f655b19277c3ee1d3d6a6fcc9&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_bd44f82f655b19277c3ee1d3d6a6fcc9 = L.map(
#                 &quot;map_bd44f82f655b19277c3ee1d3d6a6fcc9&quot;,
#                 {
#                     center: [48.33856144104875, -4.728906912669343],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 9,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_dcacbeb9a2d783636b790802a1563d0a = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_bd44f82f655b19277c3ee1d3d6a6fcc9);
#
#
#             var circle_marker_d4d7ea7121598754c311d8307e6b7804 = L.circleMarker(
#                 [48.405033, -4.924165],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 5, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_bd44f82f655b19277c3ee1d3d6a6fcc9);
#
#
#         var popup_6a50be5e662614f587c3f428a90c642c = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_f2afd16742d710ff88a5240e83d1407d = $(`&lt;div id=&quot;html_f2afd16742d710ff88a5240e83d1407d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Original 3&lt;/div&gt;`)[0];
#                 popup_6a50be5e662614f587c3f428a90c642c.setContent(html_f2afd16742d710ff88a5240e83d1407d);
#
#
#
#         circle_marker_d4d7ea7121598754c311d8307e6b7804.bindPopup(popup_6a50be5e662614f587c3f428a90c642c)
#         ;
#
#
#
#
#             var circle_marker_b1579fd908550869bc8c9dea79221701 = L.circleMarker(
#                 [48.332535, -4.617865],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 5, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_bd44f82f655b19277c3ee1d3d6a6fcc9);
#
#
#         var popup_5db3fbf8200e042ed87a8a676bdd14ec = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_0ff16cf78959948073ae72033d2987fe = $(`&lt;div id=&quot;html_0ff16cf78959948073ae72033d2987fe&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Original 5&lt;/div&gt;`)[0];
#                 popup_5db3fbf8200e042ed87a8a676bdd14ec.setContent(html_0ff16cf78959948073ae72033d2987fe);
#
#
#
#         circle_marker_b1579fd908550869bc8c9dea79221701.bindPopup(popup_5db3fbf8200e042ed87a8a676bdd14ec)
#         ;
#
#
#
#
#             var circle_marker_70b40badaa083aee18c538d43c992615 = L.circleMarker(
#                 [48.33853, -4.584715],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 5, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_bd44f82f655b19277c3ee1d3d6a6fcc9);
#
#
#         var popup_fda65d1b1121d9728be2d48d7c19624c = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_7e6312b71a953252eed106b21233b0fa = $(`&lt;div id=&quot;html_7e6312b71a953252eed106b21233b0fa&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Original 7&lt;/div&gt;`)[0];
#                 popup_fda65d1b1121d9728be2d48d7c19624c.setContent(html_7e6312b71a953252eed106b21233b0fa);
#
#
#
#         circle_marker_70b40badaa083aee18c538d43c992615.bindPopup(popup_fda65d1b1121d9728be2d48d7c19624c)
#         ;
#
#
#
#
#             var circle_marker_61790f6561aa65c7fcd7a89d9d16bf96 = L.circleMarker(
#                 [48.3829, -4.821348],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: tru

# %%
# Scatter plot
plt.scatter(o_geo_df['Longitude'], o_geo_df['Latitude'], color="blue", label='Original')
plt.scatter(geo_df['Longitude'], geo_df['Latitude'], color="red", label='Predicted')

# Set labels and title
plt.xlabel('Longitude')
plt.ylabel('Latitude')
plt.title('Original vs Predicted Vessel Positions')

# Add legend
plt.legend()

# Show the plot
plt.show()

# %% [markdown]
# # MODEL EVALUATION

# %%
from sklearn.metrics import mean_absolute_error

# %%
#Calculate prediction errors

lon_errors = y_test['lon1'] - lon_predictions
lat_errors = y_test['lat1'] - lat_predictions

o_lon_errors = y_test['lon1'] - original_lon1
o_lat_errors = y_test['lat1'] - original_lat1

#Calculate standard deviation of errors

lon_std_dev = np.std(lon_errors)
lat_std_dev = np.std(lat_errors)

o_lon_std_dev = np.std(o_lon_errors)
o_lat_std_dev = np.std(o_lat_errors)

# %%
#Print Results

print(f"Longitude Standard Deviation: {lon_std_dev}")
print(f"Latitude Standard Deviation: {lat_std_dev}")
print(f"Original Longitude Standard Deviation: {o_lon_std_dev}")
print(f"Original Latitude Standard Deviation: {o_lat_std_dev}")
# Out:
# Longitude Standard Deviation: 0.18505388387463315
# Latitude Standard Deviation: 0.15735459495609969
# Original Longitude Standard Deviation: 0.0
# Original Latitude Standard Deviation: 0.0

# %%
#Calculate Mean Squared Error.

lon_mse = mean_squared_error(y_test['lon1'], lon_predictions)
lat_mse = mean_squared_error(y_test['lat1'], lat_predictions)
print(f"Longitude MSE: {lon_mse}")
print(f"Latitude MSE: {lat_mse}")
# Out:
# Longitude MSE: 0.03425331292070336
# Latitude MSE: 0.025063161526517073

# %%
#RMSE evaluation
#perform k-fold cross-validation

lon_predictions_cv = cross_val_predict(lon_model, x_selected, y_selected['lon1'], cv=5)
lat_predictions_cv = cross_val_predict(lat_model, x_selected, y_selected['lat1'], cv=5)

lon_rmse = np.sqrt(mean_squared_error(y_selected['lon1'], lon_predictions_cv))
lat_rmse = np.sqrt(mean_squared_error(y_selected['lat1'], lat_predictions_cv))

print(f"Longitude RMSE: {lon_rmse}")
print(f"Latitude RMSE: {lat_rmse}")
# Out:
# Longitude RMSE: 0.22644512620822838
# Latitude RMSE: 0.06521414669187861

# %% [markdown]
# The fact that the RMSE results are relatively low for latitude and somewhat low for longitude could suggest that the model is performing somewhat well.

# %%
#Calculate MAE (Mean Absolute Error)

lon_mae = mean_absolute_error(y_test['lon1'], lon_predictions)
lat_mae = mean_absolute_error(y_test['lat1'], lat_predictions)

print(f"Longitude MAE: {lon_mae}")
print(f"Latitude MAE: {lat_mae}")
# Out:
# Longitude MAE: 0.13977898245917703
# Latitude MAE: 0.10004562418407259

# %%
#R-squared evaluation

lon_r2 = r2_score(y_test['lon1'], lon_predictions)
lat_r2 = r2_score(y_test['lat1'], lat_predictions)

print(f"Longitude R-squared: {lon_r2}")
print(f"Latitude R-squared: {lat_r2}")
# Out:
# Longitude R-squared: 0.1140004611628952
# Latitude R-squared: 0.026925997060987084

# %%
lon_residuals = y_test['lon1'] - lon_predictions

plt.scatter(lon_predictions, lon_residuals, color='blue')
plt.axhline(y=0, color='black', linestyle='--')
plt.xlabel('Predicted Longitude')
plt.ylabel('Residuals')
plt.title('Longitude Residual Plot')
plt.show()

# %%
lat_residuals = y_test['lat1'] - lat_predictions

plt.scatter(lat_predictions, lat_residuals, color='red')
plt.axhline(y=0, color='black', linestyle='--')
plt.xlabel('Predicted Latitude')
plt.ylabel('Residuals')
plt.title('Latitude Residual Plot')
plt.show()
